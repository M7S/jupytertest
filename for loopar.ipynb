# %% [markdown]
# I följande programmeringssekvens lär vi oss hur man enkelt upprepar något kommando i programmering (här i programmeringsspråket python)
#
# Kör programmet nedan genom att trycka på "play-knappen"

# %%
# Uppgift 1   Allting efter # är kommentarer och körs inte i programmet
print(1)
print(2)
print(3)
print("Dessa är de tre första heltalen")
print(3+5)
print("3+5")

# %% [markdown]
# Programmet gjorde det som du säkert kunde gissa, d.v.s. skrev ut de tal som finns i parentesen. Vill man skriva ut en text på skärmen måste de sättas innanför citattecken.
# Programmet utför också beräkningar innanför parentes.

# %% [markdown]
# Vill man nu att programmet ska skriva ut de 100 första heltalen kan man förstås skriva 100 st print. Copy-paste är ju trots allt ganska enkelt... MEN det blir nog ändå ganska jobbigt i längden så i alla programmeringsspråk finns det kommandon för att upprepa saker många gånger. I Pythonprogrammet anbä

# %%
# Uppgift 2
for tal in range(100):    # Efter # kommer kommentarer som inte körs i programmet. tal är en variabel som ändras varje gång loopen körs
  print(tal)              # Allt som är indraget görs varje gång i loopen
print("Denna print skrivs utanför loopen och körs bara en gång")

# %% [markdown]
# Skriver detta program ut talen 1-100? Om inte ändra programmet så att det gör det.
#
# I följande program räknar vi summan av heltalen upp till 100

# %%
# Uppgift 3
summa = 0    # Inför en variabel som vi först ger värdet 0
for tal in range(101):
  summa = summa + tal     # Varje gång loopen körs uppdateras summan genom att addera till tal
  print(summa)

# %% [markdown]
# Vad gör programmet ovan? Hur kan du ändra det så att totala summan bara skrivs ut på slutet?
#
# Ledtråd: Uppgift 2
# Gör det nedan.

# %%
# Uppgift 4
summa = 0    # Inför en variabel som vi först ger värdet 0
for tal in range(101):
  summa = summa + tal     # Varje gång loopen körs uppdateras summan genom att addera till tal
  print(summa)

# %% [markdown]
# Fundera vad följande program gör innan du kör det. Kör det sen och skriv in kommentarer i programmet.

# %%
# Uppgift 5
summa = 0    
for i in range(15):       #
  tal = 2*i               #
  print(tal)
  summa = summa + tal     #
print()                   #
print()
print(summa)              #

# %% [markdown]
# Gör ett eget program där du istället vill att programmet skriver ut de 20 första udda heltalen OCH deras summa

# %%
# Uppgift 6
summa = 0

# %% [markdown]
# Ändra programmet så att det varje gång i loopen skriver ut hur mångte talet som adderas OCH summan som dittills kommit.
#
# Ser du något matematiskt samband mellan hur mångte talet som adderas och summan så långt? Sätt in en extra print() i slutet av loopen så blir det tydligare vilka tal som hör ihop
#
# Om du tror att du hittat en matematisk regel. Testa om den stämmer med lite större tal också. Skriv också ner din regel med ord här.

# %%
# Uppgift 7

# %% [markdown]
# Skriv ett program som skriver utt de första 20 elementen i följande talföljd:
#
# 0,1,3,6,10,15,... d.v.s. en talföljd där differensen mellan elementen ökar med ett varje gång.

# %%
# Uppgift 8

# %% [markdown]
# **BONUSUPPGIFT:**
# Skriv ett program som räknar och skriver ut de första 30 st talen i Fibonaccis talföljd.
# Fibonaccis talföljd börjar: 1,1,2,3,5,8,13 och byggs så att följande tal i talföljden fås genom att addera de två föregående.
#
# Ledtråd: Här måste du ha **tre** variabler som uppdateras varje gång loopen körs.

# %%
# Fibonaccis talföljd
